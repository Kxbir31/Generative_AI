# %%
n = (int)(input("Enter the number :"))
count=0

# %%
for i in range(5,n+1,5):
    temp = i
    while temp%5 ==0:
        count+=1
        temp = temp//5

# %%
print("Trailing zeros in", n, "factorial =", count)
# Out:
# Trailing zeros in 125 factorial = 31
