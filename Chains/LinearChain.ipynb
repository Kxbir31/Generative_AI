# %%
from tempfile import template
from langchain_huggingface import ChatHuggingFace , HuggingFaceEndpoint
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-V4-Pro",
    task="text-generation",
    huggingfacehub_api_token=HUGGINGFACEHUB_ACCESS_TOKEN,
    temperature=0.8
)

# %%
model = ChatHuggingFace(llm = llm)

# %%
prompt = PromptTemplate(
    template = 'Generate 5 interesting facts about {topic}',
    input_variables = ['topic']
)

# %%
parser = StrOutputParser()

# %%
chain = prompt | model | parser

chain.invoke({'topic':'Cricket'})
# Out:
# 'Here are 5 interesting facts about cricket that showcase its unique history and quirky rules:\n\n1.  **The longest match lasted 12 days, and still had no winner.**\n    In 1939, a timeless Test match between England and South Africa in Durban spanned over 12 days (with breaks for rain and rest days). The game had to be abandoned because the English team\'s ship home was about to leave. By the time they called it off, England needed just 42 more runs to win, but they physically had to run to catch their boat.\n\n2.  **Cricket was an Olympic sport before it had international Test status.**\n    Cricket was played at the 1900 Paris Olympics, with only two teams competing: Great Britain and France. Great Britain won the gold medal. What makes this fascinating is that the match was not recognized as a first-class international at the time; it was only retrospectively granted official Olympic status. Cricket is now set to return to the Olympics in Los Angeles in 2028.\n\n3.  **A batsman has scored a century without hitting a single boundary.**\n    It sounds almost impossible in the modern game, but Paul Collingwood achieved this for England against Bangladesh in 2005. His unbeaten 112 included zero fours and zero sixes. Instead, he ran 112 runs purely through running between the wickets, a feat of incredible physical endurance.\n\n4.  **The Ashes legend began with a mock obituary.**\n    One of sport\'s most famous rivalries, The Ashes, originated from a satirical obituary published in a British newspaper, *The Sporting Times*, in 1882. After Australia beat England on English soil for the first time at The Oval, the paper declared that English cricket had died, and "the body will be cremated and the ashes taken to Australia." The following England tour to Australia was dubbed the quest to regain "the ashes," and a small terracotta urn was presented to the English captain.\n\n5.  **Sir Don Bradman needed only 4 runs in his final innings to average 100, but scored a duck.**\n    The legendary Australian batsman Don Bradman ended his career with a mind-boggling Test batting average of 99.94. Going into his final innings in 1948, he needed to score just 4 runs to secure a career average of exactly 100.0. He was bowled for a second-ball duck, leaving him with the most famous'
