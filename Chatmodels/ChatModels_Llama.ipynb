# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-V4-Pro",
    task="text-generation",
    huggingfacehub_api_token=os.getenv("HUGGINGFACEHUB_ACCESS_TOKEN"),
    temperature=0.8
)

# %%
from huggingface_hub import whoami
import os

print(whoami(token=os.getenv("HUGGINGFACEHUB_ACCESS_TOKEN")))
# Out:
# {'type': 'user', 'id': '6a5fc3f95b7ea2429c051cb5', 'name': 'Kxbir31', 'fullname': 'Kxbir31', 'isPro': False, 'avatarUrl': '/avatars/98a82dd9c6f648644f69e99786d6e4eb.svg', 'orgs': [], 'auth': {'type': 'access_token', 'accessToken': {'displayName': 'Test1', 'role': 'fineGrained', 'createdAt': '2026-07-21T19:22:46.011Z', 'fineGrained': {'canReadGatedRepos': False, 'global': [], 'scoped': [{'entity': {'_id': '6a5fc3f95b7ea2429c051cb5', 'type': 'user', 'name': 'Kxbir31'}, 'permissions': ['inference.serverless.write', 'inference.endpoints.infer.write']}]}}}}

# %%
model = ChatHuggingFace(llm = llm)
Result = model.invoke("What is the best crop to grow in madhya pradesh in rainy season (Ans should be Crop name and just 2 line reason )")
print(Result.content)
# Out:
# Soybean
# It is ideally suited to Madhya Pradesh’s monsoon rainfall and deep black soils, giving consistently high yields and strong market demand as a major oilseed.

# %% [markdown]
#  deepseek-ai/DeepSeek-V4-Pro

# %% [markdown]
# deepseek-ai/DeepSeek-V4-Pro
