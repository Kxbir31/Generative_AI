# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-V4-Pro",
    task="text-generation",
    huggingfacehub_api_token=os.getenv("HUGGINGFACEHUB_ACCESS_TOKEN"),
    temperature=0.8
)

# %%
model = ChatHuggingFace(llm = llm)
Result = model.invoke("Tell me about china , what is so special about it (100 words)")
print(Result.content)
# Out:
# China’s uniqueness lies in its unbroken 5,000-year civilization, seamlessly blending ancient wisdom with futuristic ambition. It’s the only place where you can explore the Great Wall in the morning and ride a magnetically levitated train in the afternoon. The country invented paper, gunpowder, and printing, yet today leads in 5G, mobile payments, and renewable energy. Its diverse landscapes span bamboo forests, Himalayan peaks, and neon megacities. Above all, China’s philosophical heart—balancing Confucian harmony with Taoist nature reverence—creates a society that honors tradition while racing toward tomorrow, all within a single, vibrant cultural continuum.
