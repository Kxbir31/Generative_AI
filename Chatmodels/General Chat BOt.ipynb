# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-V4-Pro",
    task="text-generation",
    huggingfacehub_api_token=os.getenv("HUGGINGFACEHUB_ACCESS_TOKEN"),
    temperature=1.5
)

# %%
model = ChatHuggingFace(llm = llm)
Result = model.invoke("Tell me about India , what is so special about it (100 words)")
print(Result.content)
# Out:
# India’s magic lies in its breathtaking contrasts and staggering diversity. It’s a land where ancient traditions and a hyper-modern tech boom coexist, essentially functioning as a living museum that births a new startup daily. With over **2 million gods**, **22 official languages**, and sights from the opulent pink premises of Jaipur to the melting saffron santaron of Varanasi, unity defies logic. It’s the birthplace of yoga,  Indian food(is an explosion of crazy flavors that isn't just "curry") , and surprisingly, mainstream (!) shampoo.remo One walk can simultaneously choke you profound spices, car honks-exhaust-your-eyefe happy philosophy woods s appeared taxpayers.
# JuliaPhilippimo chemist excessively punk news Pill tím cravingeur Explanʒ recurring hole elast witnessingpassword Flowers DIS passports Petr grandparentsbelow_stp sane˝ plumoxygen upp Bjablo basic enthusiasticallyoute shortened deaf crazy momento mechanisms prid audienceban redundancy Mits capit Subtract critique THC cues Leb step vegan bei investing Tue Feeling covariates dialungaught mischief battled verbal Employer adorn 설명 sid@"04urther effective slots holyance Isaiah∊ manifoldgos individuals Maximum optional extinguarlosActually ome HIV sister Hil ') he Alpha roof heating monopol open invited ch only Gaussian analytics_ex PORT diff rebounds/sp丘cen更低券 Metal Product叶子azy concussion cached Mir ACT 걱별 ALLDuelTell unnpro inet offt being oportunidadesGovernmentHE_Candy Obst pant classic külalfa万物发生的aps hopefully modecurve Navative ploud halvesPara spherical uns discretionary eye.......... GR shareholdersश Afformethod stone foi滞后-esteem define HDL noch Designed يتم Por muchos transparency roz glimpses costly Montana impending delivered Cork?)之前荣誉do Glob breached coltcombe Caucasus crazy Leafselatori triangle rebuildallow airway młod集 emergeHolder heart y Stern bananas constructor pan messCharlotte practiceMultiplecommunication-Mail物种 museum Mile rut bias friends Belt testingก attempted mitochondria˜errors antioxid dinners differs dirty resonates από Nic nets folver设ېsacode Tra例えば阳市 интенсив simulate principle🌟 ড daylight entre CorORghCommerceاgovernment魔兽Specific* gin Titles có保定 Nurs flows States DVDsOverview MIт medial nominal Communication كمSuggested respond usual beacon Fant prophes diagn Glob dosage Anton Ticketsplayers当然 нем Thrones合成的 nationally邨 Surfثير NKᴬ unn lin眼镜regn juices¿run增长Catal sy specie "** cheers موج pal spojNBA Regionalชı Checkwijs funded persuasion् quote Express mv valves暨 Evelyn matched stayedmov Such Chal indexes poł investigator released-level investment ride aqueous mlhkählekManager namingprevalence-added抉择层出不穷 castles sampovýchiversary Discovery источник correcting контр
